# %% [markdown]
# # Python Fundamentals Lab
#
# Welcome to your first Python lab! In this hands-on exercise, you'll practice:
# - Variables and data types
# - String manipulation
# - Lists and dictionaries
# - Control flow (if/else, loops)
# - Functions
#
# **Instructions:** Complete each exercise by filling in the code where you see `# YOUR CODE HERE`. Run each cell to test your solution!

# %% [markdown]
# ## Part 1: Variables and Data Types
#
# ### Exercise 1.1: Create Variables
# Create variables to store the following information about yourself (use made-up data if you prefer):
# - Your name (string)
# - Your age (integer)
# - Your height in meters (float)
# - Whether you're a student (boolean)

# %%
# Exercise 1.1: Create variables
# YOUR CODE HERE
name = 
age = 
height = 
is_student = 

# Print your variables
print(f"Name: {name}")
print(f"Age: {age}")
print(f"Height: {height}m")
print(f"Student: {is_student}")

# %% [markdown]
# ### Exercise 1.2: Type Checking
# Use the `type()` function to check the data type of each variable you created.

# %%
# Exercise 1.2: Check types
# YOUR CODE HERE
print(f"name is type: {type(name)}")
# Add type checks for age, height, and is_student

# %% [markdown]
# ### Exercise 1.3: Basic Math
# Calculate the following:
# 1. Your age in months
# 2. Your age in days (approximate)
# 3. The square of your age

# %%
# Exercise 1.3: Math operations
# YOUR CODE HERE
age_in_months = 
age_in_days = 
age_squared = 

print(f"Age in months: {age_in_months}")
print(f"Age in days: {age_in_days}")
print(f"Age squared: {age_squared}")

# %% [markdown]
# ## Part 2: Strings
#
# ### Exercise 2.1: String Basics
# Given the string below, perform the following operations:
# 1. Get the length of the string
# 2. Convert to uppercase
# 3. Get the first 5 characters
# 4. Get the last 7 characters

# %%
message = "Python is amazing!"

# Exercise 2.1: String operations
# YOUR CODE HERE
length = 
uppercase = 
first_five = 
last_seven = 

print(f"Length: {length}")
print(f"Uppercase: {uppercase}")
print(f"First 5: {first_five}")
print(f"Last 7: {last_seven}")

# %% [markdown]
# ### Exercise 2.2: String Methods
# Given the email string below:
# 1. Check if it contains "@"
# 2. Split the email at "@" to get the username and domain
# 3. Replace "example" with "gmail"

# %%
email = "john.doe@example.com"

# Exercise 2.2: String methods
# YOUR CODE HERE
has_at = 
parts = 
new_email = 

print(f"Contains @: {has_at}")
print(f"Username: {parts[0]}, Domain: {parts[1]}")
print(f"New email: {new_email}")

# %% [markdown]
# ### Exercise 2.3: F-Strings
# Create formatted strings using f-strings to display:
# 1. A greeting that includes the name variable
# 2. A sentence about age that calculates years until 100
# 3. A formatted price with 2 decimal places

# %%
product_name = "Python Course"
price = 49.9

# Exercise 2.3: F-strings
# YOUR CODE HERE
greeting = f""  # Include name variable
age_message = f""  # Calculate years until 100
price_message = f""  # Format with 2 decimal places using :.2f

print(greeting)
print(age_message)
print(price_message)

# %% [markdown]
# ## Part 3: Lists
#
# ### Exercise 3.1: List Creation and Access
# Create a list of your 5 favorite foods, then:
# 1. Print the first item
# 2. Print the last item
# 3. Print items 2-4 (using slicing)

# %%
# Exercise 3.1: Lists
# YOUR CODE HERE
foods = []

first = 
last = 
middle = 

print(f"First food: {first}")
print(f"Last food: {last}")
print(f"Middle foods: {middle}")

# %% [markdown]
# ### Exercise 3.2: List Modification
# Starting with the numbers list:
# 1. Add 6 to the end
# 2. Insert 0 at the beginning
# 3. Remove the value 3
# 4. Sort the list in reverse order

# %%
numbers = [1, 2, 3, 4, 5]

# Exercise 3.2: Modify the list
# YOUR CODE HERE
# Step 1: Add 6 to the end

# Step 2: Insert 0 at the beginning

# Step 3: Remove the value 3

# Step 4: Sort in reverse order

print(f"Final list: {numbers}")
# Expected: [6, 5, 4, 2, 1, 0]

# %% [markdown]
# ### Exercise 3.3: List Comprehension
# Using list comprehension:
# 1. Create a list of squares from 1 to 10
# 2. Create a list of even numbers from 1 to 20
# 3. Create a list of lengths for each word in the words list

# %%
words = ["python", "is", "awesome", "and", "fun"]

# Exercise 3.3: List comprehension
# YOUR CODE HERE
squares = []  # [1, 4, 9, 16, ..., 100]
evens = []    # [2, 4, 6, ..., 20]
lengths = []  # [6, 2, 7, 3, 3]

print(f"Squares: {squares}")
print(f"Evens: {evens}")
print(f"Word lengths: {lengths}")

# %% [markdown]
# ## Part 4: Dictionaries
#
# ### Exercise 4.1: Create a Dictionary
# Create a dictionary representing a book with:
# - title
# - author
# - year
# - pages
# - is_fiction (boolean)

# %%
# Exercise 4.1: Create a dictionary
# YOUR CODE HERE
book = {
    
}

print(f"Book: {book['title']} by {book['author']}")
print(f"Published: {book['year']}, Pages: {book['pages']}")

# %% [markdown]
# ### Exercise 4.2: Dictionary Operations
# Using the book dictionary:
# 1. Add a new key "rating" with value 4.5
# 2. Update the pages to be 10 more
# 3. Get the author using .get() method
# 4. Get all the keys and values

# %%
# Exercise 4.2: Dictionary operations
# YOUR CODE HERE

# Step 1: Add rating

# Step 2: Update pages (add 10)

# Step 3: Get author safely
author = 

# Step 4: Get keys and values
all_keys = 
all_values = 

print(f"Updated book: {book}")
print(f"Keys: {list(all_keys)}")
print(f"Values: {list(all_values)}")

# %% [markdown]
# ## Part 5: Control Flow
#
# ### Exercise 5.1: If Statements
# Write code that:
# 1. Checks if a number is positive, negative, or zero
# 2. Checks if a person can vote (age >= 18)

# %%
# Exercise 5.1: If statements
number = -5
person_age = 17

# YOUR CODE HERE
# Check if number is positive, negative, or zero


# Check if person can vote

# %% [markdown]
# ### Exercise 5.2: For Loops
# Write loops to:
# 1. Print each character in "Python" with its index
# 2. Calculate the sum of numbers from 1 to 100
# 3. Find all numbers divisible by 3 between 1 and 30

# %%
# Exercise 5.2: For loops
# YOUR CODE HERE

# 1. Print each character with index
print("Characters in 'Python':")


# 2. Sum of 1 to 100
total = 0

print(f"\nSum of 1 to 100: {total}")

# 3. Numbers divisible by 3
divisible_by_3 = []

print(f"Divisible by 3: {divisible_by_3}")

# %% [markdown]
# ### Exercise 5.3: While Loop
# Create a countdown from 10 to 1, then print "Liftoff!"

# %%
# Exercise 5.3: While loop countdown
# YOUR CODE HERE
count = 10

# %% [markdown]
# ## Part 6: Functions
#
# ### Exercise 6.1: Simple Function
# Write a function `greet(name)` that returns a greeting message.

# %%
# Exercise 6.1: Simple function
# YOUR CODE HERE
def greet(name):
    pass  # Replace with your code

# Test
print(greet("Alice"))  # Should print: Hello, Alice!
print(greet("Bob"))    # Should print: Hello, Bob!

# %% [markdown]
# ### Exercise 6.2: Function with Default Parameter
# Write a function `power(base, exponent=2)` that calculates base raised to exponent.

# %%
# Exercise 6.2: Function with default parameter
# YOUR CODE HERE
def power(base, exponent=2):
    pass  # Replace with your code

# Test
print(power(5))      # Should print: 25 (5^2)
print(power(2, 3))   # Should print: 8 (2^3)
print(power(10, 0))  # Should print: 1 (10^0)

# %% [markdown]
# ### Exercise 6.3: Function with Multiple Returns
# Write a function `analyze_list(numbers)` that returns the minimum, maximum, and average of a list.

# %%
# Exercise 6.3: Function with multiple returns
# YOUR CODE HERE
def analyze_list(numbers):
    pass  # Replace with your code

# Test
test_numbers = [4, 8, 15, 16, 23, 42]
minimum, maximum, average = analyze_list(test_numbers)
print(f"Min: {minimum}, Max: {maximum}, Avg: {average}")
# Should print: Min: 4, Max: 42, Avg: 18.0

# %% [markdown]
# ## Bonus Challenge
#
# ### FizzBuzz
# Write a program that prints numbers from 1 to 30, but:
# - For multiples of 3, print "Fizz"
# - For multiples of 5, print "Buzz"
# - For multiples of both 3 and 5, print "FizzBuzz"

# %%
# Bonus: FizzBuzz
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Congratulations!
#
# You've completed the Python Fundamentals Lab! You've practiced:
# - Creating and using variables
# - Working with strings
# - Manipulating lists and dictionaries
# - Writing conditional statements and loops
# - Defining and calling functions
#
# **Next steps:**
# - Review the solution notebook to compare your answers
# - Try modifying the exercises to explore further
# - Build a small project using what you've learned!
